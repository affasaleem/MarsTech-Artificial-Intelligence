# %%
import pandas as pd

# %%
dataset=pd.read_csv("electricity_bill.csv")

# %%
independent=dataset[["Units_Consumed"]]

# %%
dependent=dataset[["Electricity_Bill"]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
weight=regressor.coef_
weight
# Out:
# array([[8.03675359]])

# %%
bais=regressor.intercept_
bais
# Out:
# array([6.77530095])

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([[3984.96832879],
#        [3157.18270885],
#        [1557.86874412],
#        [1316.76613638],
#        [ 714.00961701],
#        [3293.80751991],
#        [1196.2148325 ],
#        [ 810.45066011],
#        [3599.20415639],
#        [3864.41702491],
#        [3502.76311329],
#        [ 416.64973412],
#        [3333.99128787],
#        [3205.4032304 ],
#        [2257.06630659],
#        [ 697.93610982],
#        [3679.57169231],
#        [1630.19952645],
#        [1453.39094743],
#        [1911.48590216],
#        [1429.28068666],
#        [1758.78758391],
#        [2771.41853646],
#        [2425.83813202],
#        [ 842.59767447],
#        [2192.77227786],
#        [3165.21946244],
#        [1694.49355518],
#        [2425.83813202],
#        [2273.13981378],
#        [1332.83964356],
#        [ 472.90700926],
#        [1051.55326785],
#        [ 931.00196398],
#        [3486.68960611],
#        [ 906.89170321],
#        [3944.78456083],
#        [1421.24393307],
# ...

# %%
x_test
# Out:
#      Units_Consumed
# 90              495
# 254             392
# 283             193
# 445             163
# 461              88
# ..              ...
# 4               156
# 318             301
# 331              58
# 245             162
# 5               121
#
# [150 rows x 1 columns]

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.9459121058046653

# %%
import pickle
filename="electricity_bill_predicion_finalized_model.sav"

# %%
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("electricity_bill_predicion_finalized_model.sav",'rb'))
result=loaded_model.predict([[535]])
# Out:
# c:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[4306.43847245]])
